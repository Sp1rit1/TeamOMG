# %% [markdown]
# Второй датасет по другой ссылке

# %%
from bs4 import BeautifulSoup
import requests
import csv

saitu = [
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=2',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=3',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=4',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=5',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=6',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=7',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=8',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=9',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=10'

]

all_links = []

for sait in saitu:
    page = requests.get(sait)
    soup = BeautifulSoup(page.text, "html.parser")
    
    nameEq = soup.findAll('div', class_='item-title')
    
    for i in nameEq:
        link_tag = i.find('a')
        if link_tag:
            name = link_tag.text.strip()
            link = f"https://e8company.ru{link_tag['href']}"
            all_links.append((name, link))
                    
# Вывод всех найденных ссылок
for name, link in all_links:
    print(f"Название: {name}")
    print(f"Ссылка: {link}")
    print('-' * 50)

file_path = 'dataset2.csv'

with open(file_path, 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(all_links)

print(f'New data appended to CSV file {file_path}')
# Out:
# Название: Теплообменник Е8-S-32 (Ду 32)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_s_32/
# --------------------------------------------------
# Название: Теплообменник Е8-GR-32 (Ду 32)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_gr_32/
# --------------------------------------------------
# Название: Теплообменник Е8-S-50 (Ду 50)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/teploobmennik_e8_s_50/
# --------------------------------------------------
# Название: Теплообменник Е8-X-50 (Ду 50)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_x_50/
# --------------------------------------------------
# Название: Теплообменник Е8-GR-50 (Ду 50)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_gr_50/
# --------------------------------------------------
# Название: Теплообменник Е8-N-65 (Ду 65)
# ...

# %% [markdown]
# Сохраняем все в один csv файл:

# %%
from bs4 import BeautifulSoup
import requests
import csv

saitu = [
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=2',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=3',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=4',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=5',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=6',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=7',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=8',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=9',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=10',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=11',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=12',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=13',
    'https://prom-partner.com/products/elektrodvigateli/obshchepromyshlennye-gost/?PAGEN_1=14',

]

all_links = []

for sait in saitu:
    page = requests.get(sait)
    soup = BeautifulSoup(page.text, "html.parser")
    
    nameEq = soup.findAll('h3', class_='tovar-h3')
    
    for i in nameEq:
        link_tag = i.find('a')
        if link_tag:
            name = link_tag.text.strip()
            link = f"https://prom-partner.com{link_tag['href']}"
            all_links.append((name, link))



saitu2 = [
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=2',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=3',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=4',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=5',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=6',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=7',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=8',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=9',
    'https://e8company.ru/catalog/teploobmenniki/?utm_source=yandex&utm_medium=cpc&utm_campaign=y.d.teploobmenniki_poisk_59696117&key=---autotargeting&region_name=Екатеринбург&utm_content=10366581671&utm_term=---autotargeting&utmstat=us%7Cyandex%7Ccid%7C59696117%7Caid%7C10366581671%7Cgid%7C4485791237%7Cpid%7C47526289519%7Ckeyword%7C---autotargeting%7Cposition_type%7Cpremium%7Csource%7Cnone%7Cregion%7C54%7Cdevice%7Cdesktop&roistat=direct2_search_10366581671_---autotargeting&roistat_referrer=none&roistat_pos=premium_3&etext=2202.BpDkvD9HPERbSTzqmTL0eRtQtG7k0Pd3d3FkfsIRo5fVWrny7LvqmNaeG16xdnUYmMsYZ7sdmdxoHedo7CTYVmlubm1hZXhlYmltY3Jycnk.d9ff4dec8440ddcd20465dc9da6a2d68f4ccdf3c&yclid=2218865770045374463&PAGEN_1=10'

]

all_links2 = []

for sait in saitu2:
    page = requests.get(sait)
    soup = BeautifulSoup(page.text, "html.parser")
    
    nameEq = soup.findAll('div', class_='item-title')
    
    for i in nameEq:
        link_tag = i.find('a')
        if link_tag:
            name = link_tag.text.strip()
            link = f"https://e8company.ru{link_tag['href']}"
            all_links2.append((name, link))
                    
# Вывод всех найденных ссылок
for name, link in all_links2:
    print(f"Название: {name}")
    print(f"Ссылка: {link}")
    print('-' * 50)

file_path = 'dataset2.csv'

with open(file_path, 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(all_links2)
    writer.writerows(all_links)

print(f'New data appended to CSV file {file_path}')
# Out:
# Название: Теплообменник Е8-S-32 (Ду 32)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_s_32/
# --------------------------------------------------
# Название: Теплообменник Е8-GR-32 (Ду 32)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_gr_32/
# --------------------------------------------------
# Название: Теплообменник Е8-S-50 (Ду 50)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/teploobmennik_e8_s_50/
# --------------------------------------------------
# Название: Теплообменник Е8-X-50 (Ду 50)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_x_50/
# --------------------------------------------------
# Название: Теплообменник Е8-GR-50 (Ду 50)
# Ссылка: https://e8company.ru/catalog/teploobmenniki/e8_teploobmenniki/e8_gr_50/
# --------------------------------------------------
# Название: Теплообменник Е8-N-65 (Ду 65)
# ...
